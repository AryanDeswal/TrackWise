# %%
from google.colab import drive

# %%
 drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from zipfile import ZipFile

# %%
# !unzip /content/drive/MyDrive/Advanced-Lane-Lines-master.zip
# Out:
# Archive:  /content/drive/MyDrive/Advanced-Lane-Lines-master.zip
# b04b492814485ed18fd90bd3b77243b03c486300
#    creating: Advanced-Lane-Lines-master/
#   inflating: Advanced-Lane-Lines-master/.gitignore
#   inflating: Advanced-Lane-Lines-master/CameraCalibration.py
#   inflating: Advanced-Lane-Lines-master/Experiment.ipynb
#   inflating: Advanced-Lane-Lines-master/LICENSE
#   inflating: Advanced-Lane-Lines-master/LaneLines.py
#   inflating: Advanced-Lane-Lines-master/PerspectiveTransformation.py
#   inflating: Advanced-Lane-Lines-master/README.md
#   inflating: Advanced-Lane-Lines-master/Thresholding.py
#    creating: Advanced-Lane-Lines-master/camera_cal/
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration1.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration10.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration11.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration12.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration13.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration14.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration15.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration16.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration17.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration18.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration19.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration2.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration20.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration3.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration4.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration5.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration6.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration7.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration8.jpg
#   inflating: Advanced-Lane-Lines-master/camera_cal/calibration9.jpg
#   inflating: Advanced-Lane-Lines-master/challenge_video.mp4
#   inflating: Advanced-Lane-Lines-master/environment.yml
#   inflating: Advanced-Lane-Lines-master/harder_challenge_video.mp4
#   inflating: Advanced-Lane-Lines-master/left_turn.png
#   inflating: Advanced-Lane-Lines-master/main.py
#    creating: Advanced-Lane-Lines-master/output_videos/
#   inflating: Advanced-Lane-Lines-master/output_videos/challenge_video_output.mp4
#   inflating: Advanced-Lane-Lines-master/output_videos/project_video_output.mp4
#   inflating: Advanced-Lane-Lines-master/project_video.mp4
#  extracting: Advanced-Lane-Lines-master/right_turn.png
#  extracting: Advanced-Lane-Lines-master/straight.png
#    creating: Advanced-Lane-Lines-master/test_images/
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_1.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_10.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_100.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_110.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_120.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_130.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_140.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_frame_2.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_test1.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/challenge_video_test2.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_1.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_10.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_100.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_1000.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_1100.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_200.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_300.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_400.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_500.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_600.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_700.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_800.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/harder_challenge_video_frame_900.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1032.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1033.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1034.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1035.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1036.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1040.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1046.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1047.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1048.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_1049.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_234.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_235.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_236.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_550.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_551.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_738.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_739.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_750.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_751.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_809.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/project_video_frame_810.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/straight_lines1.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/straight_lines2.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test1.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test2.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test3.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test4.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test5.jpg
#   inflating: Advanced-Lane-Lines-master/test_images/test6.jpg

# %%
# !pip install docopt
# Out:
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=bdc255f4571e643010b3a41ae29e5d139badf359377e9f910dff8a6838a95696
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt
# Successfully installed docopt-0.6.2

# %%
# %cd /content/Advanced-Lane-Lines-master
# Out:
# /content/Advanced-Lane-Lines-master

# %%
import numpy as np
import matplotlib.image as mpimg
import cv2
from docopt import docopt
from IPython.display import HTML
from IPython.core.display import Video
from moviepy.editor import VideoFileClip
from CameraCalibration import CameraCalibration
from Thresholding import *
from PerspectiveTransformation import *
from LaneLines import *

class FindLaneLines:
    def __init__(self):
        """ Init Application"""
        self.calibration = CameraCalibration('camera_cal', 9, 6)
        self.thresholding = Thresholding()
        self.transform = PerspectiveTransformation()
        self.lanelines = LaneLines()

    def forward(self, img):
        out_img = np.copy(img)
        img = self.calibration.undistort(img)
        img = self.transform.forward(img)
        img = self.thresholding.forward(img)
        img = self.lanelines.forward(img)
        img = self.transform.backward(img)

        out_img = cv2.addWeighted(out_img, 1, img, 0.6, 0)
        out_img = self.lanelines.plot(out_img)
        return out_img

    def process_image(self, input_path, output_path):
        img = mpimg.imread(input_path)
        out_img = self.forward(img)
        mpimg.imsave(output_path, out_img)

    def process_video(self, input_path, output_path):
        clip = VideoFileClip(input_path)
        out_clip = clip.fl_image(self.forward)
        out_clip.write_videofile(output_path, audio=False)

def main():
    findLaneLines = FindLaneLines()
    findLaneLines.process_video("/content/Advanced-Lane-Lines-master/project_video.mp4","output.mp4")

if __name__ == "__main__":
    main()
# Out:
# Moviepy - Building video output.mp4.
# Moviepy - Writing video output.mp4
# Moviepy - Done !
# Moviepy - video ready output.mp4
